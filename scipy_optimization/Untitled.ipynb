# %%
import numpy as np
x = np.linspace(-1, 1, 3)
y = np.linspace(-2, 2, 3)
X, Y = np.meshgrid(x, y)
print(x)
print(y)
print(X)
print(Y)
# Out:
# [-1.  0.  1.]
# [-2.  0.  2.]
# [[-1.  0.  1.]
#  [-1.  0.  1.]
#  [-1.  0.  1.]]
# [[-2. -2. -2.]
#  [ 0.  0.  0.]
#  [ 2.  2.  2.]]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(X.reshape((-1,)), Y.reshape((-1,)), 'o', markersize=15)
plt.grid(True)
plt.show()

# %%
def f(points_in_2d):
    X, Y = points_in_2d
    Z =  0.1*X**2 + 0.1*Y**2 + np.sin(X) + np.sin(Y) 
    return Z

# %%
x = np.linspace(-10, 10, 50)
y = np.linspace(-10, 10, 50)
X, Y = np.meshgrid(x, y)
Z = f((X,Y))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D  # <-- Note the capitalization! 
fig = plt.figure(figsize=(9, 6))
ax = Axes3D(fig)  # <-- Note the difference from your original code...
ax.plot_surface(X, Y, Z,
                rstride=2,
                cstride=2,
                cmap=mpl.cm.coolwarm,
                linewidth=0.5,
                antialiased=True)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
plt.show()

# %%
def f(points_in_2d):
    X, Y = points_in_2d
    Z =  0.1*X**2 + 0.1*Y**2 + np.sin(X) + np.sin(Y)
    if output == True:
        print('%8.4f %8.4f %8.4f' % (X, Y, Z))
    return Z

# %%
import scipy.optimize as spo
output = True
spo.brute(f, ((-10, 10.1, 5), (-10, 10.1, 5)), finish=None)
# Out:
# -10.0000 -10.0000  21.0880
# -10.0000  -5.0000  14.0029
# -10.0000   0.0000  10.5440
# -10.0000   5.0000  12.0851
# -10.0000  10.0000  20.0000
#  -5.0000 -10.0000  14.0029
#  -5.0000  -5.0000   6.9178
#  -5.0000   0.0000   3.4589
#  -5.0000   5.0000   5.0000
#  -5.0000  10.0000  12.9149
#   0.0000 -10.0000  10.5440
#   0.0000  -5.0000   3.4589
#   0.0000   0.0000   0.0000
#   0.0000   5.0000   1.5411
#   0.0000  10.0000   9.4560
#   5.0000 -10.0000  12.0851
#   5.0000  -5.0000   5.0000
#   5.0000   0.0000   1.5411
#   5.0000   5.0000   3.0822
#   5.0000  10.0000  10.9971
#  10.0000 -10.0000  20.0000
#  10.0000  -5.0000  12.9149
#  10.0000   0.0000   9.4560
#  10.0000   5.0000  10.9971
#  10.0000  10.0000  18.9120
# array([0., 0.])

# %%
output = False
opt1 = spo.brute(f, ((-10, 10.1, 5), (-10, 10.1, 5)), finish=None)
print(opt1)
print(f(opt1))
# Out:
# [0. 0.]
# 0.0

# %%
output = False
opt2 = spo.brute(f, ((-10, 10.1, 0.1), (-10, 10.1, 0.1)), finish=None)
print(opt2)
print(f(opt2))
# Out:
# [-1.3 -1.3]
# -1.5891163708343858

# %%
output = True
opt3 = spo.fmin(f, opt2, xtol=0.001, ftol=0.001, maxiter=100, maxfun=100)
print(opt3)
print(f(opt3))
# Out:
#  -1.3000  -1.3000  -1.5891
#  -1.3650  -1.3000  -1.5871
#  -1.3000  -1.3650  -1.5871
#  -1.3650  -1.2350  -1.5842
#  -1.3162  -1.3325  -1.5887
#  -1.2512  -1.3325  -1.5870
#  -1.3366  -1.3081  -1.5886
#  -1.2797  -1.3244  -1.5886
#  -1.3223  -1.3122  -1.5890
#  -1.3061  -1.2797  -1.5887
#  -1.3086  -1.2929  -1.5891
#  -1.2863  -1.2807  -1.5885
#  -1.3133  -1.3043  -1.5891
#  -1.3047  -1.3114  -1.5891
#  -1.3027  -1.3207  -1.5890
#  -1.3180  -1.3157  -1.5890
#  -1.3045  -1.3039  -1.5892
#  -1.2959  -1.3110  -1.5891
#  -1.3090  -1.3060  -1.5892
#  -1.3088  -1.2985  -1.5891
#  -1.3057  -1.3082  -1.5892
#  -1.3102  -1.3103  -1.5891
#  -1.3059  -1.3055  -1.5892
#  -1.3027  -1.3077  -1.5892
#  -1.3074  -1.3064  -1.5892
#  -1.3076  -1.3037  -1.5892
#  -1.3062  -1.3071  -1.5892
#  -1.3077  -1.3080  -1.5892
#  -1.3064  -1.3061  -1.5892
#  -1.3052  -1.3068  -1.5892
#  -1.3068  -1.3065  -1.5892
# Optimization terminated successfully.
#          Current function value: -1.589165
# ...

# %%
output = False
opt3 = spo.fmin(f, opt2, xtol=0.001, ftol=0.001, maxiter=100, maxfun=100)
print(opt3)
print(f(opt3))
# Out:
# Optimization terminated successfully.
#          Current function value: -1.589165
#          Iterations: 15
#          Function evaluations: 31
# [-1.30635734 -1.30613618]
# -1.5891646173596508

# %%
cons = ({'type': 'ineq', 'fun': lambda p: 100 - p[0] * 10 - p[1] * 10})
bnds = ((0, 1000), (0, 1000))
output = False
opt4 = spo.minimize(f, [5, 5], method='SLSQP',
                    bounds=bnds, constraints=cons)
print(opt4)
print(opt4['fun'])
print(opt4['x'])
print(f(opt4['x']))
# Out:
#      fun: 1.6631171166108079
#      jac: array([-2.45273113e-05, -2.45273113e-05])
#  message: 'Optimization terminated successfully.'
#     nfev: 20
#      nit: 5
#     njev: 5
#   status: 0
#  success: True
#        x: array([3.83743795, 3.83743793])
# 1.6631171166108079
# [3.83743795 3.83743793]
# 1.6631171166108079

# %%
print(100 - opt4['x'][0] * 10 - opt4['x'][1] * 10)
# Out:
# 23.25124113794663
